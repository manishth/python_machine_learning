# %% [markdown]
# Linear Regression:
# --------------------
#
# It is used to estimate real values (cost of houses, number of calls, total sales etc.) based on continuous variable(s).
#
# Here, we establish relationship between independent and dependent variables by fitting a best line. This best fit line is known as regression line and represented by a linear equation Y= m * X + c.
#
# X is the independent variable — the variable we are using to make predictions; m is the slope of the regression line — it represent the effect X has on Y. In other words, if X increases by 1 unit, Y will increase by exactly m units.
#
# Y = Dependent Variable<br/>
# X = Independent Variable<br/>
# m = slope<br/>
# c = intercept

# %%
from IPython.display import YouTubeVideo
# Here is a great tutorial on the least square method
YouTubeVideo("Qa2APhWjQPc")

# %% [markdown]
# The goal is to minimize the sum of the squared errors to fit a straight line to a set of data points.  (You can find further information at <a href="http://en.wikipedia.org/wiki/Linear_regression" target="_blank">Wikipedia</a>).

# %%
# Positive and Negative Linear regression
from IPython.display import display_png
display_png("http://www.statisticshowto.com/wp-content/uploads/2015/08/lin-rel.png")

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
housing_df = pd.read_csv("home_data.csv")
housing_df.head()
# Out:
#            id   price  bedrooms  sqft_living
# 0  7129300520  221900         3         1180
# 1  6414100192  538000         3         2570
# 2  5631500400  180000         2          770
# 3  2487200875  604000         4         1960
# 4  1954400510  510000         3         1680

# %%
X = housing_df["sqft_living"]
Y = housing_df["price"]

# %%
model = LinearRegression()

# %%
print("Shape of X: "+str(X.shape))
print("Shape of Y: "+str(Y.shape))
# Out:
# Shape of X: (21613,)
# Shape of Y: (21613,)

# %%
X = X.values.reshape(-1,1)

# %%
print("Shape of X: "+str(X.shape))
print("Shape of Y: "+str(Y.shape))
# Out:
# Shape of X: (21613, 1)
# Shape of Y: (21613,)

# %%
model.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Intercept: "+str(model.intercept_))
print("Coefficient: "+str(model.coef_))
# Out:
# Intercept: -43580.7403271
# Coefficient: [ 280.62356663]

# %%
plt.scatter(X, Y)
plt.plot(X, model.predict(X), c='r')
plt.show()

# %%
print("Predicted amount of 1800 sqft house: "+str(model.predict(1800)))
# Out:
# Predicted amount of 1800 sqft house: [ 461541.67961348]
